# %%
from nltk.tokenize import TweetTokenizer
import tokeniser 
from difflib import Differ

# %%
path_train_text='../dataset/hate/train_text.txt'
path_stance_train_text= '../dataset/stance/abortion/train_text.txt'

with open(path_train_text, 'r') as txt:
    hate_text= txt.readlines()


with open(path_stance_train_text, 'r') as txt:
    stance_train_text= txt.readlines()
    
our_tokeniser = tokeniser.tokenise_txt(path_train_text)

# %%
tt = TweetTokenizer()
tweet_tokeniser = []
for line in hate_text:
    tweet_tokeniser += tt.tokenize(line)

# %%
for line in hate_text[:10]:
    tweet_tokeniser += tt.tokenize(line)

print(tweet_tokeniser)
print(tokeniser.tokenise_txt(path_train_text))
# Out:
# 'Trump', 'DrainTheSwamp', 'DrainTheDeepState', 'Trump2020', 'BuildThatWall', 'Did', 'you', 'know', 'Bangladesh', 'plans', 'to', 'ship', 'over', '100', '000', 'Rohingya', 'refugees', 'to', 'a', 'tidally', 'affected', 'uninhabited', 'island', 'that', 'could', 'be', 'fully', 'submerged', 'if', 'a', 'typhoon', 'hits', 'Not', 'all', 'is', 'well', 'in', 'the', 'camps', 'either', '@user', 'report', 'amp', 'press', 'conf', '6', 'Aug', '10', '30', 'am', 'in', 'Bangkok', 'FCCT', 'From', 'our', 'client', 'Army', 'veteran', 'Miguel', 'Perez', 'to', 'Olivia', 'Segura', 's', 'family', 'https', 't', 'co', 'UrBsY84zpf', 'to', 'Alejandra', 's', 'family', 'this', 'administration', 'has', 'demonstrated', 'its', 'absolute', 'disdain', 'for', 'veterans', 'and', 'their', 'families', 'MiguelBelongsHere', 'SupportVeterans', 'ALLVeterans', 'KeepFamiliesTogether', 'Hey', 'tweeps', 'Anyone', 'know', 'and', 'willing', 'to', 'share', 'the', 'appropriate', '@user', 'or', '@user', 'editor', 'to', 'pitch', 'an', 'i
# ...

# %%
d = Differ()
difference = list(d.compare(our_tokeniser,tweet_tokeniser))
dif = []
same= []
for word in difference:
    # if word[0] not in ('+', '-'):
    # difference = difference.remove(word)
    if word[0] in ('+', '-'):
        dif.append(word)
    else:
        same.append(word)
print(dif)
# print(len(set(same))) 
#if it matches it returns the token
#if the token is only in our tokeniser it returns "-" + token
#if the token is only in tweet tokenizer it returns "+" + token
#tweet tokenizer accepts emojis, blabla talk about it in the report
# Out:
# ['+ .', '+ -', '+ …', '+ 😎', '+ ?', '+ !', '+ -', '+ ...', "+ '", '+ "', '+ ...', '- I', '- m', '+ !', "+ I'm", '- that', "+ that's", '- s', '+ 😂', '+ 😡', '+ ,', '+ ,', '+ ?', '+ ?', '+ ,', '- tweeted', '+ tweeted.And', '- And', '+ ,', '+ ,', '+ .', '+ ,', '+ ,', '+ .', "+ I'm", '- I', '- m', '+ .', '+ ~', '+ .', '+ ?', '- NGO', "+ NGO's", '- s', '+ ?', '- RefugeesNotWelcome', '+ #RefugeesNotWelcome', '- Spain', '+ #Spain', '+ :', '+ ,', '- anti', '- immigrant', '+ anti-immigrant', '+ .', '+ .', '+ ,', '+ .', '- YesAllMen', '+ #YesAllMen', '+ .', '+ .', '+ ~', '+ ~', '+ ...', '+ .', '+ ,', '+ .', '+ ...', '+ .', '+ .', '+ .', '- How', "+ How's", '- s', '+ ,', '+ ,', '+ ?', '- amp', '+ &', '- India', '- Disincentive', '+ India.Disincentive', '+ ,', '+ ,', '- BuildTheWall', '+ #BuildTheWall', '- NoAmnesty', '+ #NoAmnesty', '- NoDACA', '+ #NoDACA', '- DeportThemAll', '+ #DeportThemAll', '- KeepAmericaSafe', '+ #KeepAmericaSafe', '+ ?', '+ ?', '+ ?', '+ -', '+ ...', '- gt', '- gt', '+ ->
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c403ddb4-334f-46ca-beb7-bacf2f5feb5d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
